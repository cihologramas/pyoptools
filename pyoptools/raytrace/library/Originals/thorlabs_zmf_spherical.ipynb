# %%
from pyoptools.all import *
# Out:
# Loading component library Edmund  from files  ['/usr/lib/python3/dist-packages/pyoptools/raytrace/library/Edmund/SphOptics.cmp', '/usr/lib/python3/dist-packages/pyoptools/raytrace/library/Edmund/SphOptics1.cmp']
# Loading component library Thorlabs  from files  ['/home/richi/.pyoptools/library/Thorlabs/SphOptics1.cmp']
# Loading component library EdmundHome  from files  ['/home/richi/.pyoptools/library/EdmundHome/SphOptics.cmp']

# %%
def convert(d):
    try:
        return int(d)
    except ValueError:
        try:
            return float(d)
        except ValueError:
            return d

def zmx_read(fn):

    f=open(fn,"rU")
    data=f.read()
    return zmx_parse(data)

##Codigo tomado y modificado de https://github.com/jordens/rayopt/blob/master/rayopt/zemax.py
from struct import Struct
import numpy as np

def zmf2dict(fn):
    """Función que lee una librería de Zemax (archivo con terminación zmf), y genera un diccionario con las descripciones
    de cada componente. La llave es la referencia de cada componente
    """
    f=open(fn,"rb")
    rd={}
    head = Struct("<I")
    lens = Struct("<100sIIIIIIIdd")
    shapes = "?EBPM"
    version, = head.unpack(f.read(head.size))
    assert version in (1001, )
    while True:
        li = f.read(lens.size)
        if len(li) != lens.size:
            if len(li) > 0:
                print(f, "additional data", repr(li))
            break
        li = list(lens.unpack(li))
        li[0] = li[0].decode("latin1").strip("\0")
        li[3] = shapes[li[3]]
        description = f.read(li[7])
        assert len(description) == li[7]
        description = zmf_obfuscate(description, li[8], li[9])
        description = description.decode("latin1")
        assert description.startswith("VERS {:06d}\n".format(li[1]))
        rd[li[0]]=description
    return rd


def zmf_obfuscate(data, a, b):
    iv = np.cos(6*a + 3*b)
    iv = np.cos(655*(np.pi/180)*iv) + iv
    p = np.arange(len(data))
    k = 13.2*(iv + np.sin(17*(p + 3)))*(p + 1)
    k = (int(("{:.8e}".format(_))[4:7]) for _ in k)
    #data = np.fromstring(data, np.uint8)
    data = np.frombuffer(data, np.uint8).copy()
    data ^= np.fromiter(k, np.uint8, len(data))
    return data.tostring()

def find_key(key,lines):
    try:
        rv = list(filter(lambda x:x.startswith(key),lines))[0].split(" ",1)[1]
    except IndexError:
        # No se encontró la llave 
        rv=""
    return rv

def zmx2pyoptools(libdata,key):
    
    data=libdata[key]

    surfaces=data.splitlines()
    #Separar encabezado de los datos
    header=[]
    # Interpretar el encabezado
    while True:
        if surfaces[0].startswith("SURF"):
            break
        line=surfaces.pop(0)
        header.append(line)
    
    pyot={}
    lens_data={}

    description=find_key("NAME",header)
    lens_data["description"]=description
    
    #Aun no se que hacer con el mode
    mode=find_key("MODE",header)
    
    if mode !="SEQ":
        raise ValueError("MODE '{}'' not recognized".format(mode))
    
    unit=find_key("UNIT",header).split()[0]
    
    if unit!="MM":
        raise ValueError("UNIT '{}' not recognized".format(unit))
        
    gcat=find_key("GCAT",header)
    

    # Separar las superficies en una lista de diccionarios
    surflist=[]
    for line in surfaces:
        #Ignore empty lines
        if line.split()==[]:
            continue
        if line.startswith("SURF"):
            surflist.append(dict())
            continue
        line=line.lstrip()
        code=line[:4]
        data=line[5:].split()
        data=[convert(d) for d in data]
        surflist[-1][code]=data

    #Eliminar el plano objeto y el plano imagen

    surflist.pop(0)
    surflist.pop()


    # Identificar el tipo de lentes a partir de el numero de superficies
    # validas

    ns=len(surflist)
    
    # Normal Singlets - Need to fix for asferical lenses
    if ns==2 and ("TYPE" not in surflist[0]) and ("TYPE" not in surflist[1]) and \
    key not in ["ACA254-060-B"]: # Lista de lentes que parecen tener un error
        c0=surflist[0]["CURV"][0]
        c1=surflist[1]["CURV"][0]
        d0=surflist[0]["DISZ"][0]
        #Not all lenses have DIAM in both surfaces
        if "DIAM" in surflist[0] and "DIAM" in surflist[1]:
            r0=surflist[0]["DIAM"][0]
            r1=surflist[1]["DIAM"][0]
        elif "DIAM" in surflist[0]:
            r0=surflist[0]["DIAM"][0]
            r1=r0
        elif "DIAM" in surflist[1]:
            r0=surflist[1]["DIAM"][0]
            r1=r0
        else:
            raise ValueError("'DIAM' not defined in the surfaces")
        
        g0=surflist[0]["GLAS"][0]
        #m0=get_material(g0)


        ##c|Verificar que las superficies son iguales, si no emitir un error
        assert r0==r1
        lens_data["material"] = g0
        lens_data["glass_catalogs"] = gcat #This is not used for the moment
        lens_data["thickness"] = surflist[0]["DISZ"][0]
        lens_data["radius"] = r0
        lens_data["curvature_s2"] = surflist[1]["CURV"][0]
        lens_data["curvature_s1"] = surflist[0]["CURV"][0]
        lens_data["type"] = "SphericalLens"
        
        pyot[key]=lens_data
        return pyot
        
        ##return CL.SphericalLens(r0,d0,c0,c1,material=m0)
    
     
    elif ns==3 and 'TYPE' not in surflist[0] and 'TYPE' not in surflist[1] and 'TYPE' not in surflist[2]: #Doublets, no asphericals
        lens_data["curvature_s1"]=surflist[0]["CURV"][0]
        lens_data["curvature_s2"]=surflist[1]["CURV"][0]
        lens_data["curvature_s3"]=surflist[2]["CURV"][0]
        lens_data["thickness_l1"]=surflist[0]["DISZ"][0]
        lens_data["thickness_l2"]=surflist[1]["DISZ"][0]
        r0=surflist[0]["DIAM"][0]
        r1=surflist[1]["DIAM"][0]
        r2=surflist[2]["DIAM"][0]
        
        #Verificar que las superficies son iguales, si no emitir un error
        assert r0==r1 and r1== r2
        
        lens_data["radius"] = r0
        
        lens_data["material_l1"]=surflist[0]["GLAS"][0]
        lens_data["material_l2"]=surflist[1]["GLAS"][0]
        lens_data["glass_catalogs"] = gcat 
        #return CL.Doublet(r0,c0,c1,c2, d0,d1,m0,m1)
        lens_data["type"] = "Doublet"
        pyot[key]=lens_data
        return pyot
    
    elif ns==4 and "GLAS" not in surflist[1] and \
         'TYPE' not in surflist[0] and 'TYPE' not in surflist[1] and \
         'TYPE' not in surflist[2] and 'TYPE' not in surflist[3]: #Dobletes con espaciado en Aire
        lens_data["curvature_s1"]=surflist[0]["CURV"][0]
        lens_data["curvature_s2"]=surflist[1]["CURV"][0]
        lens_data["curvature_s3"]=surflist[2]["CURV"][0]
        lens_data["curvature_s4"]=surflist[3]["CURV"][0]

        lens_data["thickness_l1"]=surflist[0]["DISZ"][0]
        lens_data["air_gap"]=surflist[1]["DISZ"][0]
        lens_data["thickness_l2"]=surflist[2]["DISZ"][0]

        #Verificar que las superficies son iguales, si no emitir un error
        #assert r0==r1 and r1== r2 and r2 ==r3 Esto no siempre se cumple

        r0=surflist[0]["DIAM"][0]
        r1=surflist[1]["DIAM"][0]
        r2=surflist[2]["DIAM"][0]
        r3=surflist[3]["DIAM"][0]
        
        lens_data["radius"] = r0

        lens_data["material_l1"]=surflist[0]["GLAS"][0]
        # g1=surflist[1]["GLAS"][0] Este parametro no existe. Es aire
        lens_data["material_l2"]=surflist[2]["GLAS"][0]

        lens_data["glass_catalogs"] = gcat 


        #return CL.AirSpacedDoublet(r0,c0,c1,c2,c3, d0,d1,d2,m0,m1)
        lens_data["type"] = "AirSpacedDoublet"
        pyot[key]=lens_data
        return pyot
    """
    else:
        for i in surflist:
            print("*", i)
        raise ValueError # Esto toca arreglarlo y generar un error que realmente indique que está pasando
    """

# %%
d=zmf2dict("THORLABS.ZMF")

import configparser

components=configparser.ConfigParser()

for k in d:
    z=zmx2pyoptools(d,k)
    if z is not None:
        components[k]=z[k]

with open('spherical.ini', 'w') as configfile:
    components.write(configfile)

# %%
z
# Out:
# {'LA7753-G': {'description': 'Ø1" ZnSe Plano-Convex Lens, f = 1000.0 mm, AR-Coated: 7-12µm',
#   'material': 'ZNSE',
#   'glass_catalogs': 'INFRARED',
#   'thickness': 2.057495448839,
#   'radius': 12.7,
#   'curvature_s2': 0.0,
#   'curvature_s1': 0.0007129303795968849}}

# %%
d
# Out:
# {'LK4836': 'VERS 150730\nMODE SEQ\nNAME LK4836 - Plano-Concave Cylindrical Lens - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 8.331225065605\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LK4836\n  STOP\n  TYPE TOROIDAL\n  FIMP \n\n  CURV -8.695652173913040500E-002\n  PARM 0 0\n  PARM 1 0\n  PARM 2 0\n  PARM 3 0\n  PARM 4 0\n  PARM 5 0\n  PARM 6 0\n  PARM 7 0\n  PARM 8 0\n  XDAT 1 0.000000000000E+000 0 0 1.000000000000E+000 0.000000000000E+000 0 ""\n  XDAT 2 1.000000000000E+002 0 0 1.000000000000E+000 0.000000000000E+000 0 ""\n  DISZ 2\n  GLAS F_SILICA\n  DIAM 5.0 1 0 0 1 ""\n  SQAP 7.5 5.0 0\nSURF 2\n  TYPE TOROIDAL\n  FIMP \n\n  CURV 0.0\n  PARM 0 0\n  PARM 1 0\n  PARM 2 0\n  PARM 3 0\n  PARM 4 0\n  PARM 5 0\n  PARM 6 0\n  PARM 7 0\n  PARM 8 0\n  XDAT 1 0.000000000000E+000 0 0 1.000000000000E+000 0.000000000000E+000 0 ""\n  XDAT 2 1.000000000000E+002 0 0 1.000000000000E+000 0.000000000000E+000 0 ""\n  DISZ -2.590479109819E+1\n  DIAM 5.0 1 0 0 1 ""\n  SQAP 7.5 5.0 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LK4836-UV': 'VERS 150730\nMODE SEQ\nNAME LK4836 - Plano-Concave Cylindrical Lens - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 8.331225065605\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LK4836-UV\n  STOP\n  TYPE TOROIDAL\n  FIMP \n\n  CURV -8.695652173913040500E-002\n  COAT THORUV\n  PARM 0 0\n  PARM 1 0\n  PARM 2 0\n  PARM 3 0\n  PARM 4 0\n  PARM 5 0\n  PARM 6 0\n  PARM 7 0\n  PARM 8 0\n  XDAT 1 0.000000000000E+000 0 0 1.000000000000E+000 0.000000000000E+000 0 ""\n  XDAT 2 1.000000000000E+002 0 0 1.000000000000E+000 0.000000000000E+000 0 ""\n  DISZ 2\n  GLAS F_SILICA\n  DIAM 5.0 1 0 0 1 ""\n  SQAP 7.5 5.0 0\nSURF 2\n  TYPE TOROIDAL\n  FIMP \n\n  CURV 0.0\n  COAT THORUV\n  PARM 0 0\n  PARM 1 0\n  PARM 2 0\n  PARM 3 0\n  PARM 4 0\n  PARM 5 0\n  PARM 6 0\n  PARM 7 0\n  PARM 8 0\n  XDAT 1 0.000000000000E+000 0 0 1.000000000000E+000 0.000000000000E+000 0 ""\n  XDAT 2 1.000000000000E+002 0 0 1.000000000000E+000 0.000000000000E+000 0 ""\n  DISZ -2.590479109819E+1\n  DIAM 5.0 1 0 0 1 ""\n  SQAP 7.5 5.0 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LK4989': 'VERS 150730\nMODE SEQ\nNAME LK4989 - Plano-Concave Cylindrical Lens - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.687523323989E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LK4989\n  STOP\n  TYPE TOROIDAL\n  FIMP \n\n  CURV -4.347070074769600000E-003\n  PARM 0 0\n  PARM 1 0\n  PARM 2 0\n  PARM 3 0\n  PARM 4 0\n  PARM 5 0\n  PARM 6 0\n  PARM 7 0\n  PARM 8 0\n  XDAT 1 0.000000000000E+000 0 0 1.000000000000E+000 0.000000000000E+000 0 ""\n  XDAT 2 1.000000000000E+002 0 0 1.000000000000E+000 0.000000000000E+000 0 ""\n  DISZ 3.0\n  GLAS F_SILICA\n  DIAM 1.5E+1 1 0 0 1 ""\n  SQAP 2.25E+1 1.5E+1 0\nSURF 2\n  TYPE TOROIDAL\n  FIMP \n\n  CURV 0.0\n  PARM 0 0\n  PARM 1 0\n  PARM 2 0\n  PARM 3 0\n  PARM 4 0\n  PARM 5 0\n  PARM 6 0\n  PARM 7 0\n  PARM 8 0\n  XDAT 1 0.000000000000E+000 0 0 1.000000000000E+000 0.000000000000E+000 0 ""\n  XDAT 2 1.000000000000E+002 0 0 1.000000000000E+000 0.000000000000E+000 0 ""\n  DISZ -5.026163990904E+2\n  DIAM 1.5E+1 1 0 0 1 ""\n  SQAP 2.25E+1 1.5E+1 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LK4989-UV': 'VERS 150730\nMODE SEQ\nNAME LK4989 - Plano-Concave Cylindrical Lens - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.687523323989E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LK4989-UV\n  STOP\n  TYPE TOROIDAL\n  FIMP \n\n  CURV -4.347070074769600000E-003\n  COAT THORUV\n  PARM 0 0\n  PARM 1 0\n  PARM 2 0\n  PARM 3 0\n  PARM 4 0\n  PARM 5 0\n  PARM 6 0\n  PARM 7 0\n  PARM 8 0\n  XDAT 1 0.000000000000E+000 0 0 1.000000000000E+000 0.000000000000E+000 0 ""\n  XDAT 2 1.000000000000E+002 0 0 1.000000000000E+000 0.000000000000E+000 0 ""\n  DISZ 3.0\n  GLAS F_SILICA\n  DIAM 1.5E+1 1 0 0 1 ""\n  SQAP 2.25E+1 1.5E+1 0\nSURF 2\n  TYPE TOROIDAL\n  FIMP \n\n  CURV 0.0\n  COAT THORUV\n  PARM 0 0\n  PARM 1 0\n  PARM 2 0\n  PARM 3 0\n  PARM 4 0\n  PARM 5 0\n  PARM 6 0\n  PARM 7 0\n  PARM 8 0\n  XDAT 1 0.000000000000E+000 0 0 1.000000000000E+000 0.000000000000E+000 0 ""\n  XDAT 2 1.000000000000E+002 0 0 1.000000000000E+000 0.000000000000E+000 0 ""\n  DISZ -5.026163990904E+2\n  DIAM 1.5E+1 1 0 0 1 ""\n  SQAP 2.25E+1 1.5E+1 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP051919-A': 'VERS 150730\nMODE SEQ\nNAME MAP051919-A - 1/2 Inch Matched Achromatic Pair, Magnification: 1.00:1.00\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 1.19E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 4.861327E-1 1\nWAVM 2 5.875618E-1 1\nWAVM 3 6.562725E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 1.570937859976E+1\nSURF 1\n  COMM MAP051919-A\n  FIMP \n\n  CURV 1.687478906513669900E-002\n  COAT THORASLAH64\n  DISZ 1.5\n  GLAS N-SF6HT\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 2\n  FIMP \n\n  CURV 9.057971014492760500E-002\n  DISZ 4.5\n  GLAS N-BAF10\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -7.727975270479130200E-002\n  COAT THORASLAH64\n  DISZ 1.998703018339\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 1.99470363593\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 7.727975270479130200E-002\n  COAT THORASLAH64\n  DISZ 4.5\n  GLAS N-BAF10\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 6\n  FIMP \n\n  CURV -9.057971014492760500E-002\n  DISZ 1.5\n  GLAS N-SF6HT\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 7\n  FIMP \n\n  CURV -1.687478906513669900E-002\n  COAT THORASLAH64\n  DISZ 1.528153043766E+1\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP051919-B': 'VERS 150730\nMODE SEQ\nNAME MAP051919-B - 1/2 Inch Matched Achromatic Pair, Magnification: 1.00:1.00\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 1.19E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 7.065E-1 1\nWAVM 2 8.55E-1 1\nWAVM 3 1.015 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 1.537218126001E+1\nSURF 1\n  COMM MAP051919-B\n  FIMP \n\n  CURV 1.291989664082687300E-002\n  COAT THORBSLAH64\n  DISZ 1.5\n  GLAS N-SF6HT\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 2\n  FIMP \n\n  CURV 9.442870632672333000E-002\n  DISZ 4.5\n  GLAS N-BAF10\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 3\n  FIMP \n\n  CURV -8.223684210526316400E-002\n  COAT THORBSLAH64\n  DISZ 1.495\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 1.495\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 8.223684210526316400E-002\n  COAT THORBSLAH64\n  DISZ 4.5\n  GLAS N-BAF10\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 6\n  FIMP \n\n  CURV -9.442870632672333000E-002\n  DISZ 1.5\n  GLAS N-SF6HT\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 7\n  FIMP \n\n  CURV -1.291989664082687300E-002\n  COAT THORBSLAH64\n  DISZ 1.526732474248E+1\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP051925-A': 'VERS 150730\nMODE SEQ\nNAME MAP051925-A - 1/2 Inch Matched Achromatic Pair, Magnification: 1.00:1.32\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nOBNA 2.5E-1 0\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 4.861327E-1 1\nWAVM 2 5.875618E-1 1\nWAVM 3 6.562725E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 1.573154474143E+1\nSURF 1\n  COMM MAP051925-A\n  FIMP \n\n  CURV 1.687478906513669900E-002\n  COAT THORASLAH64\n  DISZ 1.5\n  GLAS N-SF6HT\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 2\n  FIMP \n\n  CURV 9.057971014492760500E-002\n  DISZ 4.5\n  GLAS N-BAF10\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -7.727975270479130200E-002\n  COAT THORASLAH64\n  DISZ 1.999114873853\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 1.999726874054\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 5.321979776476849800E-002\n  COAT THORASLAH64\n  DISZ 5.0\n  GLAS N-BAF10\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 6\n  FIMP \n\n  CURV -9.442870632672330200E-002\n  DISZ 2\n  GLAS SF10\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 7\n  FIMP \n\n  CURV -1.468860164512340000E-002\n  COAT THORASLAH64\n  DISZ 2.086844946155E+1\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP051925-B': 'VERS 150730\nMODE SEQ\nNAME MAP051925-B - 1/2 Inch Matched Achromatic Pair, Magnification: 1.00:1.32\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 1.19E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 7.065E-1 1\nWAVM 2 8.55E-1 1\nWAVM 3 1.015 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 1.555E+1\nSURF 1\n  COMM MAP051925-B\n  FIMP \n\n  CURV 1.291989664082687300E-002\n  COAT THORBSLAH64\n  DISZ 1.5\n  GLAS N-SF6HT\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 2\n  FIMP \n\n  CURV 9.442870632672333000E-002\n  DISZ 4.5\n  GLAS N-BAF10\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 3\n  FIMP \n\n  CURV -8.223684210526316400E-002\n  COAT THORBSLAH64\n  DISZ 1.705\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 1.705\nSURF 5\n  FIMP \n\n  CURV 6.180469715698393200E-002\n  COAT THORB\n  DISZ 5.0\n  GLAS N-LAK22\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 6\n  FIMP \n\n  CURV -7.513148009015777100E-002\n  DISZ 2\n  GLAS N-SF6HT\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 7\n  FIMP \n\n  CURV -1.459002042602859500E-002\n  COAT THORBSLAH64\n  DISZ 2.053539885672E+1\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP051950-A': 'VERS 150730\nMODE SEQ\nNAME MAP051950-A - 1/2 Inch Matched Achromatic Pair, Magnification: 1.00:2.63\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nOBNA 2.5E-1 0\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 4.861327E-1 1\nWAVM 2 5.875618E-1 1\nWAVM 3 6.562725E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 1.634115676015E+1\nSURF 1\n  COMM MAP051950-A\n  FIMP \n\n  CURV 1.687478906513669900E-002\n  COAT THORASLAH64\n  DISZ 1.5\n  GLAS N-SF6HT\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 2\n  FIMP \n\n  CURV 9.057971014492760500E-002\n  DISZ 4.5\n  GLAS N-BAF10\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -7.727975270479130200E-002\n  COAT THORASLAH64\n  DISZ 1.999999984749\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 1.983312228833\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 3.654970760233920000E-002\n  COAT THORA\n  DISZ 3.5\n  GLAS N-BK7\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 6\n  FIMP \n\n  CURV -4.436557231588290200E-002\n  DISZ 1.5\n  GLAS SF2\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 7\n  FIMP \n\n  CURV -1.088968746596970100E-002\n  COAT THORA\n  DISZ 4.173046895115E+1\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP051950-B': 'VERS 150730\nMODE SEQ\nNAME MAP051950-B - 1/2 Inch Matched Achromatic Pair, Magnification: 1.00:2.63\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 1.19E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 7.065E-1 1\nWAVM 2 8.55E-1 1\nWAVM 3 1.015 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 1.553E+1\nSURF 1\n  COMM MAP051950-B\n  FIMP \n\n  CURV 1.291989664082687300E-002\n  COAT THORBSLAH64\n  DISZ 1.5\n  GLAS N-SF6HT\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 2\n  FIMP \n\n  CURV 9.442870632672333000E-002\n  DISZ 4.5\n  GLAS N-BAF10\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 3\n  FIMP \n\n  CURV -8.223684210526316400E-002\n  COAT THORBSLAH64\n  DISZ 1.901\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 1.901\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 4.132231404958677800E-002\n  COAT THORBSLAH64\n  DISZ 3.5\n  GLAS N-BAF10\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 6\n  FIMP \n\n  CURV -3.732736095558044500E-002\n  DISZ 1.5\n  GLAS N-SF6HT\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 7\n  FIMP \n\n  CURV 4.000000000000000100E-003\n  COAT THORBSLAH64\n  DISZ 4.444690241466E+1\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP052550-A': 'VERS 150730\nMODE SEQ\nNAME MAP052550-A - 1/2 Inch Matched Achromatic Pair, Magnification: 1.00:2.00\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 1.19E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 4.861327E-1 1\nWAVM 2 5.875618E-1 1\nWAVM 3 6.562725E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 2.155201721576E+1\nSURF 1\n  COMM MAP052550-A\n  FIMP \n\n  CURV 1.468860164512340000E-002\n  COAT THORASLAH64\n  DISZ 2\n  GLAS SF10\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 2\n  FIMP \n\n  CURV 9.442870632672330200E-002\n  DISZ 5.0\n  GLAS N-BAF10\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -5.321979776476849800E-002\n  COAT THORASLAH64\n  DISZ 1.996594117465\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 1.997773137827\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 3.654970760233920000E-002\n  COAT THORA\n  DISZ 3.5\n  GLAS N-BK7\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 6\n  FIMP \n\n  CURV -4.436557231588290200E-002\n  DISZ 1.5\n  GLAS SF2\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 7\n  FIMP \n\n  CURV -1.088968746596970100E-002\n  COAT THORA\n  DISZ 4.589777841373E+1\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP052550-B': 'VERS 150730\nMODE SEQ\nNAME MAP052550-B - 1/2 Inch Matched Achromatic Pair, Magnification: 1.00:2.00\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 1.19E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 7.065E-1 1\nWAVM 2 8.55E-1 1\nWAVM 3 1.015 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 2.098717799194E+1\nSURF 1\n  COMM MAP052550-B\n  FIMP \n\n  CURV 1.459002042602859500E-002\n  COAT THORBSLAH64\n  DISZ 2\n  GLAS N-SF6HT\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 2\n  FIMP \n\n  CURV 7.513148009015777100E-002\n  DISZ 5.0\n  GLAS N-LAK22\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -6.180469715698393200E-002\n  COAT THORB\n  DISZ 2.106\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 2.106\nSURF 5\n  FIMP \n\n  CURV 4.132231404958677800E-002\n  COAT THORBSLAH64\n  DISZ 3.5\n  GLAS N-BAF10\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 6\n  FIMP \n\n  CURV -3.732736095558044500E-002\n  DISZ 1.5\n  GLAS N-SF6HT\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 7\n  FIMP \n\n  CURV 4.000000000000000100E-003\n  COAT THORBSLAH64\n  DISZ 4.575649872291E+1\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP103030-A': 'VERS 150730\nMODE SEQ\nNAME MAP103030-A - 1 Inch Matched Achromatic Pair, Magnification: 1.00:1.00\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.286E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 4.861327E-1 1\nWAVM 2 5.875618E-1 1\nWAVM 3 6.562725E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 2.197678364717E+1\nSURF 1\n  COMM MAP103030-A\n  FIMP \n\n  CURV 1.253132832080200100E-002\n  COAT THORASLAH64\n  DISZ 2\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 5.977286312014350200E-002\n  DISZ 1.2E+1\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -4.786979415988509800E-002\n  COAT THORASLAH64\n  DISZ 2.999827210261\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 2.999994579028\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 4.786979415988509800E-002\n  COAT THORASLAH64\n  DISZ 1.2E+1\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 6\n  FIMP \n\n  CURV -5.977286312014350200E-002\n  DISZ 2\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 7\n  FIMP \n\n  CURV -1.252979181470448300E-002\n  COAT THORASLAH64\n  DISZ 2.108569129994E+1\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP103030-B': 'VERS 150730\nMODE SEQ\nNAME MAP103030-B - 1 Inch Matched Achromatic Pair, Magnification: 1.00:1.00\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.29E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 7.065E-1 1\nWAVM 2 8.55E-1 1\nWAVM 3 1.015 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 2.235444264332E+1\nSURF 1\n  COMM MAP103030-B\n  FIMP \n\n  CURV 1.264542235710672800E-002\n  COAT THORBSLAH64\n  DISZ 1.5\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 6.180469715698393200E-002\n  DISZ 1.2E+1\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  FIMP \n\n  CURV -4.741583688952109900E-002\n  COAT THORBSLAH64\n  DISZ 1.599\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 1.6\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 4.741583688952109900E-002\n  COAT THORBSLAH64\n  DISZ 1.2E+1\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 6\n  FIMP \n\n  CURV -6.180469715698393200E-002\n  DISZ 1.5\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 7\n  FIMP \n\n  CURV -1.264542235710672800E-002\n  COAT THORBSLAH64\n  DISZ 2.22151781595E+1\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP103040-A': 'VERS 150730\nMODE SEQ\nNAME MAP103040-A - 1 Inch Matched Achromatic Pair, Magnification: 1.00:1.33\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.286E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 4.861327E-1 1\nWAVM 2 5.875618E-1 1\nWAVM 3 6.562725E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 2.242395853322E+1\nSURF 1\n  COMM MAP103040-A\n  FIMP \n\n  CURV 1.253132832080200100E-002\n  COAT THORASLAH64\n  DISZ 2\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 5.977286312014350200E-002\n  DISZ 1.2E+1\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -4.786979415988509800E-002\n  COAT THORASLAH64\n  DISZ 1.999242836875\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 1.999995578229\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 4.226542688081150200E-002\n  COAT THORA\n  DISZ 1.0E+1\n  GLAS N-BK7\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 6\n  FIMP \n\n  CURV -4.977600796416130300E-002\n  DISZ 2.5\n  GLAS SF5\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 7\n  FIMP \n\n  CURV -1.733703190013869900E-002\n  COAT THORASLAH64\n  DISZ 3.10952703136E+1\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP103040-B': 'VERS 150730\nMODE SEQ\nNAME MAP103040-B - 1 Inch Matched Achromatic Pair, Magnification: 1.00:1.33\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.29E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 7.065E-1 1\nWAVM 2 8.55E-1 1\nWAVM 3 1.015 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 2.275E+1\nSURF 1\n  COMM MAP103040-B\n  FIMP \n\n  CURV 1.264542235710672800E-002\n  COAT THORBSLAH64\n  DISZ 1.5\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 6.180469715698393200E-002\n  DISZ 1.2E+1\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -4.741583688952109900E-002\n  COAT THORBSLAH64\n  DISZ 1.9675\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 1.9675\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 3.828483920367534200E-002\n  COAT THORBSLAH64\n  DISZ 1.0E+1\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 6\n  FIMP \n\n  CURV -4.699248120300751600E-002\n  DISZ 2.5\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 7\n  FIMP \n\n  CURV -7.294478080093369500E-003\n  COAT THORBSLAH64\n  DISZ 3.159663403398E+1\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP103050-A': 'VERS 150730\nMODE SEQ\nNAME MAP103050-A - 1 Inch Matched Achromatic Pair, Magnification: 1.00:1.67\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.2E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 4.861327E-1 1\nWAVM 2 5.875618E-1 1\nWAVM 3 6.562725E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 2.231475984201E+1\nSURF 1\n  COMM MAP103050-A\n  FIMP \n\n  CURV 1.253132832080200100E-002\n  COAT THORASLAH64\n  DISZ 2\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 5.977286312014350200E-002\n  DISZ 1.2E+1\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -4.786979415988509800E-002\n  COAT THORASLAH64\n  DISZ 2.999854434136\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 2.479503862896\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 2.999400119976000000E-002\n  COAT THORASLAH64\n  DISZ 9.0\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 6\n  FIMP \n\n  CURV -4.488330341113110100E-002\n  DISZ 2.5\n  GLAS SF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 7\n  FIMP \n\n  CURV -3.435599683924800200E-003\n  COAT THORASLAH64\n  DISZ 4.089973349155E+1\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP103050-B': 'VERS 150730\nMODE SEQ\nNAME MAP103050-B - 1 Inch Matched Achromatic Pair, Magnification: 1.00:1.67\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.29E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 7.065E-1 1\nWAVM 2 8.55E-1 1\nWAVM 3 1.015 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 2.274E+1\nSURF 1\n  COMM MAP103050-B\n  FIMP \n\n  CURV 1.264542235710672800E-002\n  COAT THORBSLAH64\n  DISZ 1.5\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 6.180469715698393200E-002\n  DISZ 1.2E+1\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -4.741583688952109900E-002\n  COAT THORBSLAH64\n  DISZ 2.282\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 2.282\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 2.980625931445603900E-002\n  COAT THORB\n  DISZ 7.5\n  GLAS N-LAK22\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 6\n  FIMP \n\n  CURV -3.696857670979666900E-002\n  DISZ 1.8\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 7\n  FIMP \n\n  CURV -7.961783439490445800E-003\n  COAT THORBSLAH64\n  DISZ 4.335633602596E+1\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP103075-A': 'VERS 150730\nMODE SEQ\nNAME MAP103075-A - 1 Inch Matched Achromatic Pair, Magnification: 1.00:2.50\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.2E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 4.861327E-1 1\nWAVM 2 5.875618E-1 1\nWAVM 3 6.562725E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 2.222828382894E+1\nSURF 1\n  COMM MAP103075-A\n  FIMP \n\n  CURV 1.253132832080200100E-002\n  COAT THORASLAH64\n  DISZ 2\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 5.977286312014350200E-002\n  DISZ 1.2E+1\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -4.786979415988509800E-002\n  COAT THORASLAH64\n  DISZ 1.993340729064\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 1.99998724667\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 2.148689299527289900E-002\n  COAT THORA\n  DISZ 7.0\n  GLAS N-BK7\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 6\n  FIMP \n\n  CURV -2.948982601002650100E-002\n  DISZ 2.5\n  GLAS SF5\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 7\n  FIMP \n\n  CURV -1.046682018002930000E-002\n  COAT THORASLAH64\n  DISZ 6.560483453474E+1\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP103075-B': 'VERS 150730\nMODE SEQ\nNAME MAP103075-B - 1 Inch Matched Achromatic Pair, Magnification: 1.00:2.50\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.29E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 7.065E-1 1\nWAVM 2 8.55E-1 1\nWAVM 3 1.015 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 2.283139798183E+1\nSURF 1\n  COMM MAP103075-B\n  FIMP \n\n  CURV 1.264542235710672800E-002\n  COAT THORBSLAH64\n  DISZ 1.5\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 6.180469715698393200E-002\n  DISZ 1.2E+1\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -4.741583688952109900E-002\n  COAT THORBSLAH64\n  DISZ 2.378\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 2.379\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 2.710027100271002900E-002\n  COAT THORBSLAH64\n  DISZ 5.0\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 6\n  FIMP \n\n  CURV -2.371354043158643500E-002\n  DISZ 1.6\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 7\n  FIMP \n\n  CURV 2.393489707994255600E-003\n  COAT THORBSLAH64\n  DISZ 6.626936173919E+1\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP104040-A': 'VERS 150730\nMODE SEQ\nNAME MAP104040-A - 1 Inch Matched Achromatic Pair, Magnification: 1.00:1.00\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.2E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 4.861327E-1 1\nWAVM 2 5.875618E-1 1\nWAVM 3 6.562725E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 3.33577438673E+1\nSURF 1\n  COMM MAP104040-A\n  FIMP \n\n  CURV 1.733703190013869900E-002\n  COAT THORASLAH64\n  DISZ 2.5\n  GLAS SF5\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 4.977600796416130300E-002\n  DISZ 1.0E+1\n  GLAS N-BK7\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -4.226542688081150200E-002\n  COAT THORA\n  DISZ 1.999769574204\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 1.99977997924\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 4.226542688081150200E-002\n  COAT THORA\n  DISZ 1.0E+1\n  GLAS N-BK7\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 6\n  FIMP \n\n  CURV -4.977600796416130300E-002\n  DISZ 2.5\n  GLAS SF5\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 7\n  FIMP \n\n  CURV -1.733703190013869900E-002\n  COAT THORASLAH64\n  DISZ 3.197859930446E+1\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP104040-B': 'VERS 150730\nMODE SEQ\nNAME MAP104040-B - 1 Inch Matched Achromatic Pair, Magnification: 1.00:1.00\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.29E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 7.065E-1 1\nWAVM 2 8.55E-1 1\nWAVM 3 1.015 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 3.240189175649E+1\nSURF 1\n  COMM MAP104040-B\n  FIMP \n\n  CURV 7.294478080093369500E-003\n  COAT THORBSLAH64\n  DISZ 2.5\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 4.699248120300751600E-002\n  DISZ 1.0E+1\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  FIMP \n\n  CURV -3.828483920367534200E-002\n  COAT THORBSLAH64\n  DISZ 2.335\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 2.336\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 3.828483920367534200E-002\n  COAT THORBSLAH64\n  DISZ 1.0E+1\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 6\n  FIMP \n\n  CURV -4.699248120300751600E-002\n  DISZ 2.5\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 7\n  FIMP \n\n  CURV -7.294478080093369500E-003\n  COAT THORBSLAH64\n  DISZ 3.241169866875E+1\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP105050-A': 'VERS 150730\nMODE SEQ\nNAME MAP105050-A - 1 Inch Matched Achromatic Pair, Magnification: 1.00:1.00\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.2E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 4.861327E-1 1\nWAVM 2 5.875618E-1 1\nWAVM 3 6.562725E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 4.292641951733E+1\nSURF 1\n  COMM MAP105050-A\n  FIMP \n\n  CURV 3.435599683924800200E-003\n  COAT THORASLAH64\n  DISZ 2.5\n  GLAS SF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 4.488330341113110100E-002\n  DISZ 9.0\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -2.999400119976000000E-002\n  COAT THORASLAH64\n  DISZ 1.999963641946\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 1.999494107216\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 2.999400119976000000E-002\n  COAT THORASLAH64\n  DISZ 9.0\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 6\n  FIMP \n\n  CURV -4.488330341113110100E-002\n  DISZ 2.5\n  GLAS SF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 7\n  FIMP \n\n  CURV -3.435599683924800200E-003\n  COAT THORASLAH64\n  DISZ 4.315779576656E+1\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP105050-B': 'VERS 150730\nMODE SEQ\nNAME MAP105050-B - 1 Inch Matched Achromatic Pair, Magnification: 1.00:1.00\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.2E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 7.065E-1 1\nWAVM 2 8.55E-1 1\nWAVM 3 1.015 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 4.465009757883E+1\nSURF 1\n  COMM MAP105050-B\n  FIMP \n\n  CURV 7.961783439490445800E-003\n  COAT THORBSLAH64\n  DISZ 1.8\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 3.696857670979666900E-002\n  DISZ 7.5\n  GLAS N-LAK22\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  FIMP \n\n  CURV -2.980625931445603900E-002\n  COAT THORB\n  DISZ 2.964\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 2.965\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 2.980625931445603900E-002\n  COAT THORB\n  DISZ 7.5\n  GLAS N-LAK22\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 6\n  FIMP \n\n  CURV -3.696857670979666900E-002\n  DISZ 1.8\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 7\n  FIMP \n\n  CURV -7.961783439490445800E-003\n  COAT THORBSLAH64\n  DISZ 4.457635685446E+1\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP105075-A': 'VERS 150730\nMODE SEQ\nNAME MAP105075-A - 1 Inch Matched Achromatic Pair, Magnification: 1.00:1.50\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.2E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 4.861327E-1 1\nWAVM 2 5.875618E-1 1\nWAVM 3 6.562725E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 4.321053175751E+1\nSURF 1\n  COMM MAP105075-A\n  FIMP \n\n  CURV 3.435599683924800200E-003\n  COAT THORASLAH64\n  DISZ 2.5\n  GLAS SF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 4.488330341113110100E-002\n  DISZ 9.0\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -2.999400119976000000E-002\n  COAT THORASLAH64\n  DISZ 3.087416249991\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 2.999999995805\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 2.148689299527289900E-002\n  COAT THORA\n  DISZ 7.0\n  GLAS N-BK7\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 6\n  FIMP \n\n  CURV -2.948982601002650100E-002\n  DISZ 2.5\n  GLAS SF5\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 7\n  FIMP \n\n  CURV -1.046682018002930000E-002\n  COAT THORASLAH64\n  DISZ 6.951053993446E+1\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP105075-B': 'VERS 150730\nMODE SEQ\nNAME MAP105075-B - 1 Inch Matched Achromatic Pair, Magnification: 1.00:1.50\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.29E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 7.065E-1 1\nWAVM 2 8.55E-1 1\nWAVM 3 1.015 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 4.49E+1\nSURF 1\n  COMM MAP105075-B\n  FIMP \n\n  CURV 7.961783439490445800E-003\n  COAT THORBSLAH64\n  DISZ 1.8\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 3.696857670979666900E-002\n  DISZ 7.5\n  GLAS N-LAK22\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -2.980625931445603900E-002\n  COAT THORB\n  DISZ 3.061\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 3.061\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 2.710027100271002900E-002\n  COAT THORBSLAH64\n  DISZ 5.0\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 6\n  FIMP \n\n  CURV -2.371354043158643500E-002\n  DISZ 1.6\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 7\n  FIMP \n\n  CURV 2.393489707994255600E-003\n  COAT THORBSLAH64\n  DISZ 6.889692632731E+1\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP107575-A': 'VERS 150730\nMODE SEQ\nNAME MAP107575-A - 1 Inch Matched Achromatic Pair, Magnification: 1.00:1.00\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.2E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 4.861327E-1 1\nWAVM 2 5.875618E-1 1\nWAVM 3 6.562725E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 6.999824637003E+1\nSURF 1\n  COMM MAP107575-A\n  FIMP \n\n  CURV 1.046682018002930000E-002\n  COAT THORASLAH64\n  DISZ 2.5\n  GLAS SF5\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 2.948982601002650100E-002\n  DISZ 7.0\n  GLAS N-BK7\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -2.148689299527289900E-002\n  COAT THORA\n  DISZ 3.074044130493\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 2.999296966073\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 2.148689299527289900E-002\n  COAT THORA\n  DISZ 7.0\n  GLAS N-BK7\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 6\n  FIMP \n\n  CURV -2.948982601002650100E-002\n  DISZ 2.5\n  GLAS SF5\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 7\n  FIMP \n\n  CURV -1.046682018002930000E-002\n  COAT THORASLAH64\n  DISZ 6.981617680137E+1\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'MAP107575-B': 'VERS 150730\nMODE SEQ\nNAME MAP107575-B - 1 Inch Matched Achromatic Pair, Magnification: 1.00:1.00\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.29E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT HIKARI\nSDMA 0 1 0\nFTYP 0 0 2 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0 0\nYFLN 0 4.0\nFWGN 1 1\nWAVM 1 7.065E-1 1\nWAVM 2 8.55E-1 1\nWAVM 3 1.015 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ 6.958200597808E+1\nSURF 1\n  COMM MAP107575-B\n  FIMP \n\n  CURV -2.393489707994255600E-003\n  COAT THORBSLAH64\n  DISZ 1.6\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 2.371354043158643500E-002\n  DISZ 5.0\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  COMM  \n  FIMP \n\n  CURV -2.710027100271002900E-002\n  COAT THORBSLAH64\n  DISZ 3.157\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 4\n  STOP\n  FIMP \n\n  CURV 0.0\n  DISZ 3.158\nSURF 5\n  COMM  \n  FIMP \n\n  CURV 2.710027100271002900E-002\n  COAT THORBSLAH64\n  DISZ 5.0\n  GLAS N-BAF10\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 6\n  FIMP \n\n  CURV -2.371354043158643500E-002\n  DISZ 1.6\n  GLAS N-SF6HT\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 7\n  FIMP \n\n  CURV 2.393489707994255600E-003\n  COAT THORBSLAH64\n  DISZ 6.952494310375E+1\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 8\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
# ...
#  'LA4782-UV': 'VERS 150730\nMODE SEQ\nNAME LA4782 Plano-Convex - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 4.572E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LA4782-UV\n  STOP\n  FIMP \n\n  CURV 4.347070074769600000E-003\n  COAT THORUV\n  DISZ 4.4\n  GLAS F_SILICA\n  DIAM 2.54E+1 1 0 0 1 ""\n  FLAP 0 2.54E+1 0\nSURF 2\n  FIMP \n\n  CURV 0.0\n  COAT THORUV\n  DISZ 4.968343859364E+2\n  DIAM 2.54E+1 1 0 0 1 ""\n  FLAP 0 2.54E+1 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LA4795': 'VERS 150730\nMODE SEQ\nNAME LA4795 Plano-Convex - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 6.75E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LA4795\n  STOP\n  FIMP \n\n  CURV 1.086838387131829900E-002\n  DISZ 1.098E+1\n  GLAS F_SILICA\n  DIAM 3.75E+1 1 0 0 1 ""\n  FLAP 0 3.75E+1 0\nSURF 2\n  FIMP \n\n  CURV 0.0\n  DISZ 1.873937407158E+2\n  DIAM 3.75E+1 1 0 0 1 ""\n  FLAP 0 3.75E+1 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LA4795-UV': 'VERS 150730\nMODE SEQ\nNAME LA4795 Plano-Convex - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 6.75E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LA4795-UV\n  STOP\n  FIMP \n\n  CURV 1.086838387131829900E-002\n  COAT THORUV\n  DISZ 1.098E+1\n  GLAS F_SILICA\n  DIAM 3.75E+1 1 0 0 1 ""\n  FLAP 0 3.75E+1 0\nSURF 2\n  FIMP \n\n  CURV 0.0\n  COAT THORUV\n  DISZ 1.873937407158E+2\n  DIAM 3.75E+1 1 0 0 1 ""\n  FLAP 0 3.75E+1 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LA4855': 'VERS 150730\nMODE SEQ\nNAME LA4855 Plano-Convex - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 4.572E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LA4855\n  STOP\n  FIMP \n\n  CURV 7.245326764237099700E-003\n  DISZ 5.35\n  GLAS F_SILICA\n  DIAM 2.54E+1 1 0 0 1 ""\n  FLAP 0 2.54E+1 0\nSURF 2\n  FIMP \n\n  CURV 0.0\n  DISZ 2.9520489205E+2\n  DIAM 2.54E+1 1 0 0 1 ""\n  FLAP 0 2.54E+1 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LA4855-UV': 'VERS 150730\nMODE SEQ\nNAME LA4855 Plano-Convex - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 4.572E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LA4855-UV\n  STOP\n  FIMP \n\n  CURV 7.245326764237099700E-003\n  COAT THORUV\n  DISZ 5.35\n  GLAS F_SILICA\n  DIAM 2.54E+1 1 0 0 1 ""\n  FLAP 0 2.54E+1 0\nSURF 2\n  FIMP \n\n  CURV 0.0\n  COAT THORUV\n  DISZ 2.9520489205E+2\n  DIAM 2.54E+1 1 0 0 1 ""\n  FLAP 0 2.54E+1 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LA4874': 'VERS 150730\nMODE SEQ\nNAME LA4874 Plano-Convex - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.286E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LA4874\n  STOP\n  FIMP \n\n  CURV 1.449065352847410000E-002\n  DISZ 3.17\n  GLAS F_SILICA\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 0.0\n  DISZ 1.472636076399E+2\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LA4874-UV': 'VERS 150730\nMODE SEQ\nNAME LA4874 Plano-Convex - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.286E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LA4874-UV\n  STOP\n  FIMP \n\n  CURV 1.449065352847410000E-002\n  COAT THORUV\n  DISZ 3.17\n  GLAS F_SILICA\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 0.0\n  COAT THORUV\n  DISZ 1.472636076399E+2\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LA4904': 'VERS 150730\nMODE SEQ\nNAME LA4904 Plano-Convex - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 4.572E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LA4904\n  STOP\n  FIMP \n\n  CURV 1.449065352847410000E-002\n  DISZ 7.84\n  GLAS F_SILICA\n  DIAM 2.54E+1 1 0 0 1 ""\n  FLAP 0 2.54E+1 0\nSURF 2\n  FIMP \n\n  CURV 0.0\n  DISZ 1.415910541973E+2\n  DIAM 2.54E+1 1 0 0 1 ""\n  FLAP 0 2.54E+1 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LA4904-UV': 'VERS 150730\nMODE SEQ\nNAME LA4904 Plano-Convex - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 4.572E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LA4904-UV\n  STOP\n  FIMP \n\n  CURV 1.449065352847410000E-002\n  COAT THORUV\n  DISZ 7.84\n  GLAS F_SILICA\n  DIAM 2.54E+1 1 0 0 1 ""\n  FLAP 0 2.54E+1 0\nSURF 2\n  FIMP \n\n  CURV 0.0\n  COAT THORUV\n  DISZ 1.415910541973E+2\n  DIAM 2.54E+1 1 0 0 1 ""\n  FLAP 0 2.54E+1 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LA4917': 'VERS 150730\nMODE SEQ\nNAME LA4917 Plano-Convex - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 5.4\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LA4917\n  STOP\n  FIMP \n\n  CURV 1.449275362318840900E-001\n  DISZ 2.18\n  GLAS F_SILICA\n  DIAM 3.0 1 0 0 1 ""\n  FLAP 0 3.0 0\nSURF 2\n  FIMP \n\n  CURV 0.0\n  DISZ 1.307086582876E+1\n  DIAM 3.0 1 0 0 1 ""\n  FLAP 0 3.0 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LA4917-UV': 'VERS 150730\nMODE SEQ\nNAME LA4917 Plano-Convex - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 5.4\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LA4917-UV\n  STOP\n  FIMP \n\n  CURV 1.449275362318840900E-001\n  COAT THORUV\n  DISZ 2.18\n  GLAS F_SILICA\n  DIAM 3.0 1 0 0 1 ""\n  FLAP 0 3.0 0\nSURF 2\n  FIMP \n\n  CURV 0.0\n  COAT THORUV\n  DISZ 1.307086582876E+1\n  DIAM 3.0 1 0 0 1 ""\n  FLAP 0 3.0 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LA4924': 'VERS 150730\nMODE SEQ\nNAME LA4924 Plano-Convex - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.286E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LA4924\n  STOP\n  FIMP \n\n  CURV 1.242081728977770100E-002\n  DISZ 3.0\n  GLAS F_SILICA\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 0.0\n  DISZ 1.725318922415E+2\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LA4924-UV': 'VERS 150730\nMODE SEQ\nNAME LA4924 Plano-Convex - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 2.286E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LA4924-UV\n  STOP\n  FIMP \n\n  CURV 1.242081728977770100E-002\n  COAT THORUV\n  DISZ 3.0\n  GLAS F_SILICA\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 2\n  FIMP \n\n  CURV 0.0\n  COAT THORUV\n  DISZ 1.725318922415E+2\n  DIAM 1.27E+1 1 0 0 1 ""\n  FLAP 0 1.27E+1 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LA4936': 'VERS 150730\nMODE SEQ\nNAME LA4936 Plano-Convex - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 1.143E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LA4936\n  STOP\n  FIMP \n\n  CURV 7.246376811594200400E-002\n  DISZ 3.34\n  GLAS F_SILICA\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 2\n  FIMP \n\n  CURV 0.0\n  DISZ 2.671998715099E+1\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LA4936-UV': 'VERS 150730\nMODE SEQ\nNAME LA4936 Plano-Convex - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 1.143E+1\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nCOFN "COATING.DAT" "SCATTER_PROFILE.DAT" "ABG_DATA.DAT" "PROFILE.GRD"\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LA4936-UV\n  STOP\n  FIMP \n\n  CURV 7.246376811594200400E-002\n  COAT THORUV\n  DISZ 3.34\n  GLAS F_SILICA\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 2\n  FIMP \n\n  CURV 0.0\n  COAT THORUV\n  DISZ 2.671998715099E+1\n  DIAM 6.35 1 0 0 1 ""\n  FLAP 0 6.35 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  'LA4966': 'VERS 150730\nMODE SEQ\nNAME LA4966 Plano-Convex - UV Fused Silica\nNOTE 0 FOR INFORMATION ONLY, NOT FOR MANUFACTURING.  ALL VALUES AND COATING(S) ARE TYPICAL AND THEORETICAL, ACTUAL PERFORMANCE MAY VARY.  FOR FURTHER INFORMATION CONTACT CUSTOMER SERVICE AT TECHSUPPORT@THORL\nNOTE 0 ABS.COM\nPFIL 0 0 0\nLANG 0\nUNIT MM X W X CM MR CPMM\nENPD 5.4\nENVD 2.0E+1 1 0\nGFAC 0 0\nGCAT SCHOTT INFRARED MISC\nSDMA 0 1 0\nFTYP 0 0 1 3 0 0 0\nROPD 2\nPICB 1\nXFLN 0\nYFLN 0\nFWGN 1\nWAVM 1 4.861E-1 1\nWAVM 2 5.876E-1 1\nWAVM 3 6.563E-1 1\nPWAV 2\nGLRS 1 0\nSURF 0\n  FIMP \n\n  CURV 0.0\n  DISZ INFINITY\nSURF 1\n  COMM LA4966\n  STOP\n  FIMP \n\n  CURV 7.246376811594200400E-002\n  DISZ 1.82\n  GLAS F_SILICA\n  DIAM 3.0 1 0 0 1 ""\n  FLAP 0 3.0 0\nSURF 2\n  FIMP \n\n  CURV 0.0\n  DISZ 2.857271124482E+1\n  DIAM 3.0 1 0 0 1 ""\n  FLAP 0 3.0 0\nSURF 3\n  FIMP \n\n  CURV 0.0\n  DISZ 0\n',
#  ...}
